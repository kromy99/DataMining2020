# %% [markdown]
# # Assignment 2: Clustering

# %%
import pandas as pd

# %% [markdown]
# ## Data: Credit Card User Data
# For this assignment, we use credit card data from 9000 users. Source: https://www.kaggle.com/arjunbhasin2013/ccdata

# %%
data = pd.read_csv("DATA/CC GENERAL.csv")
data.set_index('CUST_ID')
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# ...

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# ### Task 1: clean the data and perform a basic EDA

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
data.shape
# Out:
# (8950, 18)

# %%
duplicate_rows_df = data[data.duplicated()]
print(duplicate_rows_df.shape)
duplicate_rows_df.head()
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [CUST_ID, BALANCE, BALANCE_FREQUENCY, PURCHASES, ONEOFF_PURCHASES, INSTALLMENTS_PURCHASES, CASH_ADVANCE, PURCHASES_FREQUENCY, ONEOFF_PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY, CASH_ADVANCE_FREQUENCY, CASH_ADVANCE_TRX, PURCHASES_TRX, CREDIT_LIMIT, PAYMENTS, MINIMUM_PAYMENTS, PRC_FULL_PAYMENT, TENURE]
# Index: []

# %%
data.count()
# Out:
# CUST_ID                             8950
# BALANCE                             8950
# BALANCE_FREQUENCY                   8950
# PURCHASES                           8950
# ONEOFF_PURCHASES                    8950
# INSTALLMENTS_PURCHASES              8950
# CASH_ADVANCE                        8950
# PURCHASES_FREQUENCY                 8950
# ONEOFF_PURCHASES_FREQUENCY          8950
# PURCHASES_INSTALLMENTS_FREQUENCY    8950
# CASH_ADVANCE_FREQUENCY              8950
# CASH_ADVANCE_TRX                    8950
# PURCHASES_TRX                       8950
# CREDIT_LIMIT                        8949
# PAYMENTS                            8950
# MINIMUM_PAYMENTS                    8637
# PRC_FULL_PAYMENT                    8950
# TENURE                              8950
# dtype: int64

# %%
df = data.dropna() 
df.count()
# Out:
# CUST_ID                             8636
# BALANCE                             8636
# BALANCE_FREQUENCY                   8636
# PURCHASES                           8636
# ONEOFF_PURCHASES                    8636
# INSTALLMENTS_PURCHASES              8636
# CASH_ADVANCE                        8636
# PURCHASES_FREQUENCY                 8636
# ONEOFF_PURCHASES_FREQUENCY          8636
# PURCHASES_INSTALLMENTS_FREQUENCY    8636
# CASH_ADVANCE_FREQUENCY              8636
# CASH_ADVANCE_TRX                    8636
# PURCHASES_TRX                       8636
# CREDIT_LIMIT                        8636
# PAYMENTS                            8636
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                    8636
# TENURE                              8636
# dtype: int64

# %%
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
data.boxplot(column=[ 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
       'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],figsize=(12,12))

# %%
plt.matshow(data.cov())

# %%
data.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000151E2B7B7C0>,
# ...
#       dtype=object)

# %%
#sns.pairplot(data, diag_kws={'bins': 10})

# %%
plt.scatter(data["BALANCE"], data["PAYMENTS"])

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
plt.scatter(data["BALANCE"], data["CREDIT_LIMIT"])

# %%
plt.scatter(data["BALANCE"], data["PURCHASES"])

# %% [markdown]
# ### Task 2: Cluster the creditcard users into sub-groups. Perform a statistical analysis of these grpuops.
# * use a Scikit-Learn clustering algorithm of your choice to group the users
# * analyze the key differences between the user groups

# %%
from sklearn import cluster, datasets, mixture
from sklearn.cluster import KMeans
data = pd.read_csv("DATA/CC GENERAL.csv")
data.set_index('CUST_ID')
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# ...

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataNoID = data.drop(["CUST_ID"],axis=1)
dataNoID = dataNoID.dropna()

# %%
np.any(np.isnan(dataNoID))
# Out:
# False

# %%
dataNoID.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
kmeans = KMeans(n_clusters=2,init='k-means++')
kmeans.fit(dataNoID)
kmeans = kmeans.predict(dataNoID)

# %%
dataNoID["KMEANS"] = kmeans

# %%
dataNoID.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(dataNoID.iloc[:, 0], dataNoID.iloc[:, 2], c=kmeans, s=15)

# %%
plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(dataNoID.iloc[:, 0], dataNoID.iloc[:, 12], c=kmeans, s=15)

# %%
plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(dataNoID.iloc[:, 0], dataNoID.iloc[:, 13], c=kmeans, s=15)

# %%
plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(dataNoID.iloc[:, 2], dataNoID.iloc[:, 13], c=kmeans, s=15)

# %%
dataNoID.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
G = dataNoID.groupby(dataNoID['KMEANS'])

# %%
G["BALANCE"].describe()
# Out:
#          count         mean          std      min          25%          50%  \
# KMEANS
# 0       1841.0  3905.447843  3096.735711  0.48805  1132.386178  3515.039029
# 1       6795.0   976.931375  1075.028888  0.00000    95.848561   653.931902
#
#                 75%           max
# KMEANS
# 0       5825.470945  19043.138560
# 1       1465.856359   5965.535557

# %%
G["PURCHASES"].describe()
# Out:
#          count         mean          std  min      25%      50%      75%  \
# KMEANS
# 0       1841.0  2424.565280  4074.875710  0.0  100.000  1022.77  3248.83
# 1       6795.0   646.360892   893.196749  0.0   35.955   317.40   877.02
#
#              max
# KMEANS
# 0       49039.57
# 1        8591.31

# %%
G["CREDIT_LIMIT"].describe()
# Out:
#          count         mean          std     min     25%     50%      75%  \
# KMEANS
# 0       1841.0  9891.148585  3472.270757  1200.0  7500.0  9000.0  11500.0
# 1       6795.0  3067.428048  1955.875968    50.0  1500.0  2500.0   4000.0
#
#             max
# KMEANS
# 0       30000.0
# 1       10000.0

# %%
G["PAYMENTS"].describe()
# Out:
#          count         mean          std        min          25%          50%  \
# KMEANS
# 0       1841.0  4399.406885  5133.937668  31.845894  1400.282454  2543.033209
# 1       6795.0  1076.003648  1126.127236   0.049513   347.217197   676.487532
#
#                 75%          max
# KMEANS
# 0       5693.080357  50721.48336
# 1       1380.294017  10893.77844

# %%
G.corr()
# Out:
#                                           BALANCE  BALANCE_FREQUENCY  \
# KMEANS
# 0      BALANCE                           1.000000           0.334743
#        BALANCE_FREQUENCY                 0.334743           1.000000
#        PURCHASES                        -0.018248           0.106125
#        ONEOFF_PURCHASES                 -0.029029           0.088972
#        INSTALLMENTS_PURCHASES            0.011576           0.087416
#        CASH_ADVANCE                      0.335237           0.035975
#        PURCHASES_FREQUENCY              -0.177844           0.230032
#        ONEOFF_PURCHASES_FREQUENCY       -0.205421           0.186292
#        PURCHASES_INSTALLMENTS_FREQUENCY -0.077116           0.205352
#        CASH_ADVANCE_FREQUENCY            0.401640           0.162031
#        CASH_ADVANCE_TRX                  0.284382           0.127296
#        PURCHASES_TRX                    -0.010972           0.177491
# ...

# %%
#plt.matshow(G.cov())

# %%
G.boxplot(column=[ 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
       'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],figsize=(20,14))
# Out:
# 0         AxesSubplot(0.1,0.15;0.363636x0.75)
# 1    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
G.boxplot(column=[ 'CASH_ADVANCE_TRX', 'PURCHASES_TRX'],figsize=(20,14))
# Out:
# 0         AxesSubplot(0.1,0.15;0.363636x0.75)
# 1    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
import seaborn as sns
# %matplotlib inline

corr = G.corr()

 
           

fig, ax = plt.subplots(figsize=(12,12))  
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        linewidths=1,
        ax = ax)
